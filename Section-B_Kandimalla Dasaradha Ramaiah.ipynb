# %% [markdown]
# # Q11. Predict the output. Why does the second line behave differently from the first?
# exoutput:
# this is an 3x3 materix of two at location of [0][0] for two will be 99
# m1=[99 0 0
#     0 0  0
#     0 0  0]
# m2=[99 0  0
#      0 0  0
#     0  0  0]
# output:
# [[99, 0, 0], [0, 0, 0], [0, 0, 0]]
# [[99, 0, 0], [99, 0, 0], [99, 0, 0]]
# explanation:i cant understand what the for loop can do in thats and instized variable _ is not used any were also
# for second is blend guss
# #Q12. Predict the output:x = [1, 2, 3] y = x x = x + [4] print("x =", x) print("y =", y) a = [1, 2, 3] b = a a += [4] print("a =", a) print("b =", b) Now answer: Why do `x = x + [4]` and `a += [4]` behave differently?
# exoutput:the result of x = [1, 2, 3] y = x x = x + [4] print("x =", x) print("y =", y)
# x is [5,6,7] and y is [1,2,3]
# a = [1, 2, 3]
# b = a
# a += [4]
# print("a =", a)
# print("b =", b)
# for thsi a is [1,2,3,[4]] and b is[1,2,3]
# output:x = [1, 2, 3, 4]y = [1, 2, 3]a = [1, 2, 3, 4]b = [1, 2, 3, 4]
# explantion:the list have functions like add and insert and append so is not gone performing i think but in qustion given behave differently so ot have answer so i think on the way
# # Q13. Predict the output. What is the value of `i` after the loop ends, and why?for i in range(5): pass print(i) for j in range(0): pass print(j) think before you write
# exoutput: for i the answer is 4
# and j is 0
# output:
# 4
# ERROR!
# Traceback (most recent call last):
#   File "<main.py>", line 6, in <module>
# NameError: name 'j' is not defined
# explantion:the value is passing so loop go run full it give an finall value thats way but is i and j are insame for loop like initized why the error is beacse the loop in empty not run to pass the value
# # Q14. Predict the output of each print statement. Then state which lines will raise an error (if any).
# #print("10" + "20")
# #print(10 + 20)
# #print("10" * 3)
# #print(10 * "3")
# #print("10" + 20)
# #print(int("10") + 20)
# exoutput:
# 1.1020
# 2.30
# 3."10""10""10"
# 4."10""10""10""10""10""10""10""10""10""10"
# 5.same as above "10""10""10""10""10""10""10""10""10""10"
# 6.there is an possiablty to get an error if not is value "10"+20
# 7.30
# output
# 1.1020
# 2.30
# 3.101010
# 4.3333333333
# 5.ERROR!
# 6.30
# explantion:
# the 3 and 4 i think thats multpy them like i think and print retuns all so i also mentioned " is marks
# #Q15. Predict the output. Then explain Python's short-circuit evaluation in one line.
# #print(0 or 5)
# #print(5 or 0)
# #print(None or "hello")
# #print(0 and 5)
# #print(5 and 10)
# #print([] or "default")
# #print([0] or "default")
# # careful!
# exoutput:
# 1.0
# 2.5
# 3.hello
# 4.maybe is 0
# 5.50 or 15
# 6.emnty
# 7.error
# output:
# 5
# 5
# hello
# 0
# 10
# default
# [0]
# explantion:
# or is goes like which is first thats gone take as output beacse there is no conditon to tell but it go like ture values and fales value like and for same data goes max value
