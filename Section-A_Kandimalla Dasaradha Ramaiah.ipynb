# %% [markdown]
# # 1.What is the difference between the `is` operator and the `==` operator? Give one example where
# two variables return True for `==` but False for `is`.
# the differnce btw "is" and "==" in here == means these of values in one thats exactly maches to the seconed one and coming is that refers to spcics like in normal is mean from or to be it means it belongs something.
# ex: a=10
# b=10
# if a==b:
#   print("true")
# else:
#   print("flase")
# if a is b:
#   print("true")
# else:
#   print("flase")
# #  Q2. Classify the following as Mutable or Immutable: list, tuple, set, dict, str, int, float, bool,frozenset. Explain in one line WHY immutability matters in real code.
# fistly what is mutable : mutable means thats can be created we can delted or able to change it or can be added ,ex:list,set,dict
# immutable: that can be created and deletd onec we assigns values we cant changes like uniqe ids,ex:tuple,str,int,float,bool
# # Q3 .Predict the output of `print(0.1 + 0.2 == 0.3)`. Then explain WHY this happens. (Hint: it is not a Python bug.)
# the output is true
# 0.3==0.3 these values are exacly equal so it returns the result like its an conditoln for an example we can use the if loop like it go inside block if thats condion is true in the print staetment it prints or displays  the contant if we pass argguments thats can excutes and print the resuelt
# # Q4. Both list and tuple can store ordered collections. Give 3 concrete situations where you would CHOOSE a tuple over a list, and explain the reasoning behind each.
# 1.data in tuple these cant be modifes in an immutables ones
# 2.data is perminemtnt and high security
# 3.fast accesing the data
# # Q5. Why is dictionary lookup O(1) on average while searching for a value in a list using `in` is O(n)? Explain in plain English without using the word "hash" - then explain it again WITH the word "hash".
# if all the books had the same call number
# it would be incredily unhelpful and youre back to O(n).
# If a lot of your books — say 1/100 of them — have the same call number, its a lot better than looking through all the books, but O(n/100) is still O(n).
# You need to make sure that your values hash code doesnt change or you wont be able to find it in your hash table.
# the hash table thats stores values if use hash thats know where the exact location of searhing value it returns in a single step
# # Q6. What is the difference between `range()` and `numpy.arange()`? Mention at least 3 differences,one of them should involve floats.
# 1.numpy.arange(), is the type of function thas is used to create n dimonisions arrys these values also come in countious like range also perform operations
# and range() this manly we can see in for loops it have itartions like start,stop,changings_value,these all we can do we cant perform operations or not any arrys can be created
# #Q7. What is the difference between `list.append(x)`, `list.extend(x)`, and `list.insert(i, x)`? For each, show what happens when `x = [4, 5]` is added to `a = [1, 2, 3]`.
# 1.listappend()
# this is a function thats adds list at last of persent list
# a=[1,2,3]
# a.append([4,5])
# print(a)
# result: [1, 2, 3, [4, 5]]
# 2.lsitextend()
# this also adds but every elements individulas to the last
# a=[1,2,3]
# a.extend([4,5])
# print(a)
# result:[1, 2, 3, 4, 5]
# 3.list.insert(i,x)
# this spcical one is also used to add elements but we can aslo prouived the index of the place to add the list
# #Q7. What does this line do, and what are the values of a, b, c after execution?a, *b, c = [10, 20, 30, 40, 50]Now, what happens if you write: `a, *b, c = [10, 20]` ? And `a, *b, c = [10]` ?
# 1.a,*b,c=[10,20,30,40,50]
# in the list of a is going to take first elemnt of 10 and last elemnmt of 50 goes to c and remaing all are go to b
# 2.a,*b,c=[10,20]
# in the list of a is going to take first elemnt of 10 and last elemnmt of 20 goes to c and remaing all are go to b if not there thats means is an emty one or null
# 3.a,*b,c=[10,20]
# unlink above this will given error due to it at least needed a two values
# # Q9. Explain the difference between `/`, `//`, `%`, and `**` operators in Python. For each, give the output of the operation when applied to (-7, 2).
# 1./ is a division this goto divied the -7/2 as a result is -3.5
# 2.// this name is floor division this also perform like division but the result will be an integer not a float
# result:-4
# 3.% is name is moduluess thats give remineder of division for -7%2 the remaninder is 1
# 4.** this an exponentiation thats is uesd to give x power y like we used in maths like for the 7 power 2 is 49
# # Q10. Why is NumPy significantly faster than Python lists for numerical operations? Give 3 reasons, at least one should mention memory layout.
# 1.list are can be to store differnt datatypes but the numpy only in a single type
# 2.for memory assces the lists are store in differnt ways but numpy thats single block thast near to cpu to run
# 3.to perform math operations we need to use loop but in numpy we can give instrctions to run
